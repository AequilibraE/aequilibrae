# %%
# Imports
from uuid import uuid4
from tempfile import gettempdir
from os.path import join
from aequilibrae import Project
import folium

from aequilibrae.project.network.ovm_downloader import OVMDownloader
# sphinx_gallery_thumbnail_path = 'images/nauru.png'

# %%
# We create an empty project on an arbitrary folder
fldr = join(gettempdir(), uuid4().hex)
project = Project()
project.new(fldr)

# %%
# Now we can download the network from any place in the world (as long as you have memory for all the download
# and data wrangling that will be done)

# We can create from a bounding box or a named place.
# For the sake of this example, we will choose the small nation of Nauru.
# project.network.create_from_ovm(west=148.7077, south=-20.2780, east=148.7324, north=-20.2621, data_source=r'C:\Users\penny\git\Aequilibrae\tests\data\overture\theme=transportation', output_dir=r'C:\Users\penny\git\Aequilibrae\tests\data\overture\theme=transportation')
# bbox = [148.7077, -20.2780, 148.7324, -20.2621 ]

project.network.create_from_ovm(west=153.1771, south=-27.6851, east=153.2018, north=-27.6703, data_source=r'C:\Users\penny\git\data\theme=transportation', output_dir=r'C:\Users\penny\git\Aequilibrae\tests\data\overture\theme=transportation')
brisbane_bbox = [153.1771, -27.6851, 153.2018, -27.6703]
# links = download[0]
# nodes = download[1]
# Out:
# C:\Users\penny\git\Aequilibrae\aequilibrae\project\network\ovm_downloader.py:210: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_result = pd.concat(result_dfs, ignore_index=True)
# C:\Users\penny\git\Aequilibrae\aequilibrae\project\network\ovm_downloader.py:264: UserWarning: Geometry column does not contain geometry.
#   final_result['geometry'] = final_result['geometry'].astype(str)

# %%
# We grab all the links data as a Pandas DataFrame so we can process it easier
links = project.network.links.data

# We create a Folium layer
network_links = folium.FeatureGroup("links")

# We do some Python magic to transform this dataset into the format required by Folium
# We are only getting link_id and link_type into the map, but we could get other pieces of info as well
for i, row in links.iterrows():
    points = row.geometry.wkt.replace("LINESTRING ", "").replace("(", "").replace(")", "").split(", ")
    points = "[[" + "],[".join([p.replace(" ", ", ") for p in points]) + "]]"
    # we need to take from x/y to lat/long
    points = [[x[1], x[0]] for x in eval(points)]

    line = folium.vector_layers.PolyLine(
        points, popup=f"<b>link_id: {row.link_id}</b>", tooltip=f"{row.link_type}", color="blue", weight=10
    ).add_to(network_links)

# %%
# We get the center of the region we are working with some SQL magic
# long = (bbox[0]+bbox[2])/2
# lat = (bbox[1]+bbox[3])/2
long = (brisbane_bbox[0]+brisbane_bbox[2])/2
lat = (brisbane_bbox[1]+brisbane_bbox[3])/2

# %%
map_osm = folium.Map(location=[lat, long], zoom_start=14)
network_links.add_to(map_osm)
folium.LayerControl().add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e823238fda08dda1581c3cde5c0ea20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e823238fda08dda1581c3cde5c0ea20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e823238fda08dda1581c3cde5c0ea20 = L.map(
#                 &quot;map_8e823238fda08dda1581c3cde5c0ea20&quot;,
#                 {
#                     center: [-27.6777, 153.18945],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db0263140f99941e918f37a343fc5c2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db0263140f99941e918f37a343fc5c2c.addTo(map_8e823238fda08dda1581c3cde5c0ea20);
#
#
#             var feature_group_8a2041c638f5ab2d3385824e73a6b1fc = L.featureGroup(
#                 {}
#             );
#
#
#             var poly_line_3c17c42418643d85e9dd7a43e31fcb77 = L.polyline(
#                 [[-27.681885, 153.179988], [-27.681868, 153.179968], [-27.681848, 153.179954], [-27.681825, 153.179946]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_8a2041c638f5ab2d3385824e73a6b1fc);
#
#
#         var popup_82eb3f310cc96471adb3a5ee5bdb4079 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af0736a20a861c001fd7806be09f2933 = $(`&lt;div id=&quot;html_af0736a20a861c001fd7806be09f2933&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;link_id: 1&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_82eb3f310cc96471adb3a5ee5bdb4079.setContent(html_af0736a20a861c001fd7806be09f2933);
#
#
#
#         poly_line_3c17c42418643d85e9dd7a43e31fcb77.bindPopup(popup_82eb3f310cc96471adb3a5ee5bdb4079)
#         ;
#
#
#
#
#             poly_line_3c17c42418643d85e9dd7a43e31fcb77.bindTooltip(
#                 `&lt;div&gt;
#                      tertiary
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_65acabffab85cfd355d19fb3ba30e3db = L.polyline(
#                 [[-27.683722, 153.18881], [-27.683814, 153.18886], [-27.683967, 153.188937], [-27.684408, 153.189158]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_8a2041c638f5ab2d3385824e73a6b1fc);
#
#
#         var popup_839485f337b10f93cfa71b7e3befa8d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf134b425cbca7fb8c119090b5333b01 = $(`&lt;div id=&quot;html_bf134b425cbca7fb8c119090b5333b01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;link_id: 2&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_839485f337b10f93cfa71b7e3befa8d7.setContent(html_bf134b425cbca7fb8c119090b5333b01);
#
#
#
#         poly_line_65acabffab85cfd355d19fb3ba30e3db.bindPopup(popup_839485f337b10f93cfa71b7e3befa8d7)
#         ;
#
#
#
#
#             poly_line_65acabffab85cfd355d19fb3ba30e3db.bindTooltip(
#                 `&lt;div&gt;
#                      tertiary
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_59f80b6da94660c2d0d01de17984e7e4 = L.polyline(
#                 [[-27.684408, 153.189158], [-27.684491, 153.189202], [-27.68494, 153.189437]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_8a2041c638f5ab2d3385824e73a6b1fc);
#
#
#         var popup

# %%
project.close()
